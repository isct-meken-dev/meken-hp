# %%
# %pip install pathlib
# %pip install Pillow

import re
import shutil
from pathlib import Path
from PIL import Image


def main(original_dir, working_dir):
    original_path = Path(original_dir).resolve()
    working_path = Path(working_dir).resolve()

    match original_path.exists(), working_path.exists():
        case True, True:
            shutil.rmtree(working_path)
            shutil.copytree(original_path, working_path)
        case True, False:
            shutil.copytree(original_path, working_path)
        case _:
            raise ValueError("Invalid directory states")

    extensions = {".png", ".jpg", ".jpeg"}
    sizes = {"sml": 640, "med": 1280, "big": 1920}

    size_limits = {k: (v, v) for k, v in sizes.items()}
    pattern = re.compile("\.(" + "|".join(sizes.keys()) + ")$")

    path_list = list(working_path.rglob("*"))

    for path in path_list:
        if path.suffix in extensions:
            try:
                img = Image.open(path)
                
                limit_key = None
                
                if match := pattern.search(path.stem):
                    limit_key = match.group(1)
                    new_stem = pattern.sub("", path.stem)
                else:
                    new_stem = path.stem

                if limit_key:
                    max_size = size_limits[limit_key]
                    img.thumbnail(max_size, Image.Resampling.LANCZOS)

                webp_path = path.with_name(f"{new_stem}.webp")

                img.save(webp_path, "webp", quality=80, method=6)

                path.unlink()
                print(f"Replaced: {path.name} -> {webp_path.name}")

            except Exception as e:
                print(f"Error processing {path}: {e}")


main("../../asset/images.bak", "../../asset/images")
# Out:
# Requirement already satisfied: pathlib in ./env/lib/python3.11/site-packages (1.0.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Pillow in ./env/lib/python3.11/site-packages (12.2.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Replaced: circle_meken_bw-1.png -> circle_meken_bw-1.webp
# Replaced: meken.concept.big.jpeg -> meken.concept.webp
# Replaced: meken.icon.med.png -> meken.icon.webp
# Replaced: コミケ_6.jpg -> コミケ_6.webp
# Replaced: 上映会_2.png -> 上映会_2.webp
# Replaced: 講義室_1.jpg -> 講義室_1.webp
# Replaced: meken.top.big.png -> meken.top.webp
# Replaced: work.024.001.character_design.med.png -> work.024.001.character_design.webp
# Replaced: 合宿_3.jpg -> 合宿_3.webp
# Replaced: 制作_5.png -> 制作_5.webp
# Replaced: 制作_4.png -> 制作_4.webp
# Replaced: imag.png -> imag.webp
# Replaced: icon_kita.jpg -> icon_kita.webp
# Replaced: blog.026.007のコピー.png -> blog.026.007のコピー.webp
# Replaced: icon_zundamon.png -> icon_zundamon.webp
# Replaced: icon_gyuutan.png -> icon_gyuutan.webp
# Replaced: icon_usi.png -> icon_usi.webp
# Replaced: icon_ela.png -> icon_ela.webp
# Replaced: icon_asagi.png -> icon_asagi.webp
# Replaced: icon_el.png -> icon_el.webp
# Replaced: work.024.001.icon.med.png -> work.024.001.icon.webp
# Replaced: work.024.001.detail.med.jpg -> work.024.001.detail.webp
# Replaced: work.020.001.icon.med.png -> work.020.001.icon.webp
# Replaced: work.021.001.detail.med.jpg -> work.021.001.detail.webp
# Replaced: work.021.001.icon.med.png -> work.021.001.icon.webp
# Replaced: 20.png -> 20.webp
# Replaced: 22.png -> 22.webp
# Replaced: work.020.001.detail.med.jpeg -> work.020.001.detail.webp
# Replaced: 24.png -> 24.webp
